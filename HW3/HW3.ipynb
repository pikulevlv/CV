# %% [markdown]
# # Dogs vs. Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %% [markdown]
# Классификация изображений: Cats vs Dogs
#
# Обучить модель классификации изображений на 2 класса.
#
# Исходные данные и валидация решения на kaggle в рамках контеста Cats vs Dogs.
#
# Решения необходимо прислать в виде ipython-ноутбука с указанием значения метрики на Leaderboard.
#
# Задание засчитывается при значениях метрики Log Loss меньше 0.3.

# %%
import numpy as np
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input 
from tensorflow.keras.preprocessing.image import load_img, img_to_array
#from keras.preprocessing import image

# %%
IMG_SIZE = (224, 224)  # размер входного изображения сети

# %% [markdown]
# ## Функции загрузки данных

# %%
import re
import random
from random import shuffle
#from glob import glob
import glob
import numpy as np
from  scipy import ndimage
import PIL
from PIL import Image


train_files = glob.glob('../input/train/*.jpg')
test_files = glob.glob('../input/test/*.jpg')
#train_files = glob.glob('./train/*.jpg')
#test_files = glob.glob('./test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = load_img(path, target_size=target_size)  # загрузка и масштабирование изображения
    img=img.transpose(random.choice(range(4)))     #Аугментации не было, поэтому поповорачиваем

    array = img_to_array(img)

    return preprocess_input(array)  # предобработка для VGG16

# генератор для последовательного чтения обучающих данных с диска
def fit_generator(files, batch_size=32):
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if re.match('.*/dog\.\d', path) else 0. for path in files[i:j]])
            yield (x, y)

# генератор последовательного чтения тестовых данных с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %%
print(len(test_files))
print(len(train_files))
# Out:
# 12500
# 25000

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(i // 5 + 1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%s' % path.split('/')[-1]);

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model -  объект класса keras.models.Model (Functional Model)
base_model = VGG16(include_top = False, #архитектура VGG16 прибита гвоздями. можно поменять
                   # из документации: whether to include the fully-connected layer at the top of the network
                   weights = 'imagenet',
                   input_shape = (IMG_SIZE[0], IMG_SIZE[1], 3))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 5s 0us/step

# %%
# фиксируем все веса предобученной сети
#len(base_model.layers)=19
for layer in base_model.layers: # делаем сеть не тренируемой, можно не все слои блокировать
    layer.trainable = False

# %%
for layer in base_model.layers[-2:]: # последние два слоя хотел сделать тренируемыми, но как-то не задалось
    layer.trainable = True

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 2,359,808
# Non-trainable params: 12,354,880
# _________________________________________________________________

# %% [markdown]
# ![](http://)## Добавляем полносвязный слой и сверточные слои

# %%
x = base_model.layers[-1].output # берем выход 1 с конца слоя нашей модели (пробовал второй с конца, получил плато)
x = keras.layers.Conv2D(kernel_size = (3,3), filters = 512, activation='sigmoid', kernel_regularizer=keras.regularizers.l1(1e-4))(x)
x = keras.layers.Conv2D(kernel_size = (5,5), filters = 256, activation='sigmoid', kernel_regularizer=keras.regularizers.l1(1e-4))(x)

x = keras.layers.Flatten()(x) # вытягиваем в вектор
x = keras.layers.Dense(1,  # добавляем один полносвязный слой
                activation='sigmoid',  # функция активации  
                kernel_regularizer=keras.regularizers.l1(1e-4))(x)
model = Model(inputs=base_model.input, outputs=x) # и снова обучаем эту модель

# %%
for layer in base_model.layers: 
    layer.trainable = False
for layer in base_model.layers[-5:]: 
    layer.trainable = True

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 5, 5, 512)         2359808
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 1, 1, 256)         3277056
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 20,351,809
# Trainable params: 12,716,545
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer=keras.optimizers.Adam(lr=3e-4), #keras.optimizers.Adam(lr=0.00003, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.01, amsgrad=False)
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss # т.к. всего 2 класса
              metrics=['accuracy'])

# %%
shuffle(train_files)  # перемешиваем обучающую выборку

train_val_split = 100  # число изображений в валидационной выборке

validation_data = next(fit_generator(train_files[:train_val_split], train_val_split))

# запускаем процесс обучения
model.fit_generator(fit_generator(train_files[train_val_split:]),  # данные читаем функцией-генератором
        steps_per_epoch=20,  # число вызовов генератора за эпоху
        epochs=200,  # число эпох обучения
        validation_data=validation_data)
# Out:
# Epoch 1/200
# 20/20 [==============================] - 8s 409ms/step - loss: 6.4671 - acc: 0.5766 - val_loss: 5.9042 - val_acc: 0.6800
# Epoch 2/200
# 20/20 [==============================] - 3s 145ms/step - loss: 5.3751 - acc: 0.8266 - val_loss: 4.9528 - val_acc: 0.8200
# Epoch 3/200
# 20/20 [==============================] - 3s 167ms/step - loss: 4.5865 - acc: 0.8922 - val_loss: 4.1436 - val_acc: 0.9300
# Epoch 4/200
# 20/20 [==============================] - 3s 165ms/step - loss: 3.8921 - acc: 0.9125 - val_loss: 3.5419 - val_acc: 0.9100
# Epoch 5/200
# 20/20 [==============================] - 3s 167ms/step - loss: 3.3087 - acc: 0.9297 - val_loss: 3.0403 - val_acc: 0.9100
# Epoch 6/200
# 20/20 [==============================] - 3s 165ms/step - loss: 2.8343 - acc: 0.9281 - val_loss: 2.6573 - val_acc: 0.9100
# Epoch 7/200
# 20/20 [==============================] - 3s 164ms/step - loss: 2.4792 - acc: 0.9094 - val_loss: 2.2236 - val_acc: 0.9300
# Epoch 8/200
# 20/20 [==============================] - 3s 166ms/step - loss: 2.1475 - acc: 0.9266 - val_loss: 1.9077 - val_acc: 0.9600
# Epoch 9/200
# 20/20 [==============================] - 3s 168ms/step - loss: 1.9404 - acc: 0.9047 - val_loss: 1.7544 - val_acc: 0.9300
# Epoch 10/200
# 20/20 [==============================] - 3s 168ms/step - loss: 1.7008 - acc: 0.9328 - val_loss: 1.5892 - val_acc: 0.9200
# Epoch 11/200
# 20/20 [==============================] - 3s 169ms/step - loss: 1.4754 - acc: 0.9453 - val_loss: 1.4177 - val_acc: 0.9200
# Epoch 12/200
# 20/20 [==============================] - 3s 165ms/step - loss: 1.3102 - acc: 0.9422 - val_loss: 1.3095 - val_acc: 0.9200
# Epoch 13/200
# 20/20 [==============================] - 3s 170ms/step - loss: 1.2221 - acc: 0.9297 - val_loss: 1.2155 - val_acc: 0.9100
# Epoch 14/200
# 20/20 [==============================] - 3s 170ms/step - loss: 1.0955 - acc: 0.9469 - val_loss: 1.0831 - val_acc: 0.9100
# Epoch 15/200
# 20/20 [==============================] - 3s 173ms/step - loss: 0.9867 - acc: 0.9500 - val_loss: 0.9395 - val_acc: 0.9400
# Epoch 16/200
# 20/20 [==============================] - 3s 164ms/step - loss: 0.9091 - acc: 0.9453 - val_loss: 0.8615 - val_acc: 0.9400
# Epoch 17/200
# 20/20 [==============================] - 3s 170ms/step - loss: 0.9438 - acc: 0.9187 - val_loss: 0.8158 - val_acc: 0.9400
# Epoch 18/200
# 20/20 [==============================] - 3s 168ms/step - loss: 0.8303 - acc: 0.9203 - val_loss: 0.7922 - val_acc: 0.9200
# Epoch 19/200
# 20/20 [==============================] - 3s 172ms/step - loss: 0.7347 - acc: 0.9516 - val_loss: 0.6197 - val_acc: 0.9700
# Epoch 20/200
# 20/20 [==============================] - 3s 166ms/step - loss: 0.6786 - acc: 0.9469 - val_loss: 0.6300 - val_acc: 0.9600
# Epoch 21/200
# 20/20 [==============================] - 3s 169ms/step - loss: 0
200
# 20/20 [==============================] - 3s 166ms/step - loss: 0.1328 - acc: 0.9766 - val_loss: 0.1461 - val_acc: 0.9600
# Epoch 177/200
# 20/20 [==============================] - 3s 172ms/step - loss: 0.1289 - acc: 0.9828 - val_loss: 0.1487 - val_acc: 0.9700
# Epoch 178/200
# 20/20 [==============================] - 3s 170ms/step - loss: 0.1329 - acc: 0.9844 - val_loss: 0.1580 - val_acc: 0.9800
# Epoch 179/200
# 20/20 [==============================] - 3s 170ms/step - loss: 0.1124 - acc: 0.9859 - val_loss: 0.1367 - val_acc: 0.9800
# Epoch 180/200
# 20/20 [==============================] - 3s 167ms/step - loss: 0.1154 - acc: 0.9859 - val_loss: 0.1426 - val_acc: 0.9800
# Epoch 181/200
# 20/20 [==============================] - 3s 168ms/step - loss: 0.1171 - acc: 0.9781 - val_loss: 0.1338 - val_acc: 0.9700
# Epoch 182/200
# 20/20 [==============================] - 3s 172ms/step - loss: 0.1420 - acc: 0.9781 - val_loss: 0.1553 - val_acc: 0.9600
# Epoch 183/200
# 20/20 [==============================] - 4s 177ms/step - loss: 0.1711 - acc: 0.9781 - val_loss: 0.1603 - val_acc: 0.9700
# Epoch 184/200
# 20/20 [==============================] - 3s 171ms/step - loss: 0.1472 - acc: 0.9766 - val_loss: 0.2050 - val_acc: 0.9500
# Epoch 185/200
# 20/20 [==============================] - 3s 167ms/step - loss: 0.1273 - acc: 0.9875 - val_loss: 0.1404 - val_acc: 0.9700
# Epoch 186/200
# 20/20 [==============================] - 3s 166ms/step - loss: 0.1106 - acc: 0.9875 - val_loss: 0.1308 - val_acc: 0.9700
# Epoch 187/200
# 20/20 [==============================] - 3s 167ms/step - loss: 0.1242 - acc: 0.9828 - val_loss: 0.1585 - val_acc: 0.9600
# Epoch 188/200
# 20/20 [==============================] - 3s 167ms/step - loss: 0.1240 - acc: 0.9859 - val_loss: 0.1848 - val_acc: 0.9700
# Epoch 189/200
# 20/20 [==============================] - 3s 163ms/step - loss: 0.1412 - acc: 0.9812 - val_loss: 0.2359 - val_acc: 0.9400
# Epoch 190/200
# 20/20 [==============================] - 3s 169ms/step - loss: 0.1656 - acc: 0.9766 - val_loss: 0.1714 - val_acc: 0.9700
# Epoch 191/200
# 20/20 [==============================] - 3s 168ms/step - loss: 0.1483 - acc: 0.9844 - val_loss: 0.1769 - val_acc: 0.9700
# Epoch 192/200
# 20/20 [==============================] - 3s 170ms/step - loss: 0.1294 - acc: 0.9797 - val_loss: 0.1618 - val_acc: 0.9700
# Epoch 193/200
# 20/20 [==============================] - 3s 168ms/step - loss: 0.1606 - acc: 0.9828 - val_loss: 0.1676 - val_acc: 0.9800
# Epoch 194/200
# 20/20 [==============================] - 3s 169ms/step - loss: 0.1617 - acc: 0.9781 - val_loss: 0.1641 - val_acc: 0.9700
# Epoch 195/200
# 20/20 [==============================] - 3s 168ms/step - loss: 0.1143 - acc: 0.9891 - val_loss: 0.1654 - val_acc: 0.9800
# Epoch 196/200
# 20/20 [==============================] - 3s 161ms/step - loss: 0.1361 - acc: 0.9828 - val_loss: 0.1535 - val_acc: 0.9700
# Epoch 197/200
# 20/20 [==============================] - 3s 162ms/step - loss: 0.1394 - acc: 0.9828 - val_loss: 0.1498 - val_acc: 0.9800
# Epoch 198/200
# 20/20 [==============================] - 3s 161ms/step - loss: 0.1170 - acc: 0.9859 - val_loss: 0.1290 - val_acc: 0.9800
# Epoch 199/200
# 20/20 [==============================] - 3s 168ms/step - loss: 0.1188 - acc: 0.9906 - val_loss: 0.1640 - val_acc: 0.9700
# Epoch 200/200
# 20/20 [==============================] - 3s 168ms/step - loss: 0.1293 - acc: 0.9828 - val_loss: 0.1607 - val_acc: 0.9700

# %%
model.save('cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
pred = model.predict_generator(predict_generator(test_files), len(test_files), max_queue_size=500)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, (path, score) in enumerate(zip(test_files[80:][:10], pred[80:][:10]), 1):
    subplot = fig.add_subplot(i // 5 + 1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%.3f' % score);

# %% [markdown]
# ## Готовим данные для сабмита

# %%
with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, pred):
        dst.write('%s,%f\n' % (re.search('(\d+)', path).group(0), np.round_(score)))

# %%
with open('submit_2.csv', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, pred):
        dst.write('%s,%f\n' % (re.search('(\d+)', path).group(0), np.round_(score)))

# %%
# LogLoss = 1.011

# %%
pred.shape
# Out:
# (12500, 1)

# %%
from IPython.display import Image
Image("Screenshot_1.jpg", width=500, height=300)
